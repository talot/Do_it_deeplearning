# %% [markdown]
# <h1> This is the first colab notebook!

# %% [markdown]
# 1. print test

# %%
print("hello dudu")
# Out:
# hello dudu

# %% [markdown]
# 2. list

# %%
my_list = [10, 'hello list', 20]
print(my_list)
my_list2 = [[10,20,30],[40,50,60]]
print(my_list2)
print(my_list2[1][1])
# Out:
# [10, 'hello list', 20]
# [[10, 20, 30], [40, 50, 60]]
# 50

# %% [markdown]
# 3. ready to numpy

# %%
import numpy as np
print(np.__version__)
import matplotlib.pyplot as plt
# Out:
# 1.18.4

# %% [markdown]
# 4. numpy array

# %%
my_arr = np.array([[10, 20, 30],[40, 50, 60]])
print(my_arr)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
print(type(my_arr))
# Out:
# <class 'numpy.ndarray'>

# %%
type(my_arr)
# Out:
# numpy.ndarray

# %%
ma01 = my_arr[0][2]
print(ma01)
# Out:
# 30

# %%
sum_ma = np.sum(my_arr)
print(sum_ma)
# Out:
# 210

# %%
plt.plot([1, 2, 3, 4, 5],[1, 4, 9, 16, 25])
plt.show()

# %%
plt.scatter([1, 2, 3, 4, 5],[1, 4, 9, 16, 25])
plt.show()

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)
# print(x)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# 5. Linear Regression

# %%
from sympy import Symbol, solve

# slope
a
# intercept
b
# x
x = 3
x1 = 5
# y
y = 25
y1 = 39  
y = (a*x)+b
y1 = (a*x1)+b
#a = (y-b)/x
#x = (y-b)/a

print(a)
print(b)
# Out:
# 0
# 0

# %%
y = Symbol('') 
equation1 = x + 2 * y - 3 
equation2 = 3 * x - y + 2 
solve((equation1, equation2), dict=True)

# %%
def simultaneous_eq(a,b):
    if a[0] == 0:
        y = Fraction(a[2], a[1])
        x = Fraction(b[2] - b[1]*y, b[0])
    elif a[1] == 0:
        x = Fraction(a[2], a[0])
        y = Fraction(b[2] - b[0]*x, b[1])
    elif b[0] == 0:
        y = Fraction(b[2], b[1])
        x = Fraction(a[2] - a[1]*y, a[0])
    elif b[1] == 0:
        x = Fraction(b[2], b[0])
        y = Fraction(a[2] - a[0]*x, a[1])
    else:
        a = np.array(a)
        b = np.array(b)
        c = b* Fraction(a[0],b[0])
        d = a - c
        y = Fraction(d[2],d[1])
        x = Fraction(a[2]-a[1]*y,a[0])
    return x, y
# Out:
#   File "<ipython-input-73-6c03fd463257>", line 20
#     x = Fraction(a[2]-a[1]*y,a[0])
#                                   ^
# IndentationError: unindent does not match any outer indentation level

# %%
c = [[5,2], [2,1]]
d = [14,4]
result = np.linalg.solve(c,d)
print(result)

e = [[5,2,1], [2,-3,-4], [1,5,-2]]
f = [14,4,21]
result2 = np.linalg.solve(e,f)
print(result2)
# Out:
# [ 6. -8.]
# [ 2.06293706  2.92307692 -2.16083916]
